# %% [markdown]
# This Notebook runs the **[Deep Reasoning Networks (DRNets)](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence)** repository on Kaggle Notebook. The repository has two main parts:
#
# - [Crystal Structure Phase Mapping](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Crystal-Structure-Phase-Mapping)
# - [Games](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Games)
#
#
# This notebook runs the **Games** part which is further subdivided into:
#
# - [MNIST_Sudoku_4x4](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Games/MNIST_Sudoku_4x4)
# - [MNIST_Sudoku_9x9](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Games/MNIST_Sudoku_9x9)
#
# This Notebook runs **MNIST_Sudoku_4x4**

# %%
#Clone the GitHub repo to a local directory named DRNets
# !git clone https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence.git DRNets
# Out:
# Cloning into 'DRNets'...
# remote: Enumerating objects: 269, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 269 (delta 0), reused 0 (delta 0), pack-reused 266
# Receiving objects: 100% (269/269), 148.32 MiB | 27.91 MiB/s, done.
# Resolving deltas: 100% (118/118), done.
# Updating files: 100% (224/224), done.

# %%
#Move into the MNIST_Sudoku_4x4 directory
# %cd /kaggle/working/DRNets/Games/MNIST_Sudoku_4x4
# Out:
# /kaggle/working/DRNets/Games/MNIST_Sudoku_4x4

# %%
#  Generate Sudoku data where each digit is sampled from the MNIST test set (takes 
# about 2-3 mins)
# !bash generate_data.sh
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (10000, 16, 1, 32, 32)
# (10000, 16)
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (10000, 16, 1, 32, 32)
# (10000, 16)

# %% [markdown]
# This repo uses a pre-trained conditional GAN model. But if you want to train it from scratch, you can run the following cell.

# %%
# (Optional) train a conditional GAN model from scratch. A pretrained model is 
# provided at ./models/G-180.pt , if you prefer to skip this step.

#python3 cgan.py

# %%
# Solve mixed Sudokus. On a machine with an NVIDIA Tesla V100 GPU, it takes 
# about 30mins to converge. Manually terminate the training when it has 
# converged to the desired criteria (otherwise it will run the maximum number 
# of epochs).
# !python3 sep.py
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# use cuda
# ...
# 100%|██████████████████████████| 9912422/9912422 [00:00<00:00, 118654852.98it/s]
# Extracting ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100%|██████████████████████████████| 28881/28881 [00:00<00:00, 152563846.13it/s]
# Extracting ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100%|███████████████████████████| 1648877/1648877 [00:00<00:00, 42207129.41it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...
# 100%|█████████████████████████████████| 4542/4542 [00:00<00:00, 33131354.38it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# ...

# %% [markdown]
# **I have manually stopped further training. But if want, you can let it run for the maximum number of epochs.**

# %% [markdown]
# **For the experimental setting where the overlapping Sudoku puzzles can share digits:**

# %%
# Generate Sudoku data where <x> and <y> define the range of values for the 
# second puzzle (the first puzzle is assumed to still use the digits 1-4). 

# x should be between 1 and 5, and y=x+3.

#!python3 gen_data_common_digits.py --st1 1 --ed1 4 --st2 <x> --ed2 <y>

#You can change the values for x and y in the following line. For reference,
#you can see the above line. I chose x = 2 and y = 5. You can choose whatever you want.

# !python3 gen_data_common_digits.py --st1 1 --ed1 4 --st2 2 --ed2 5
# Out:
# (10000, 16, 1, 32, 32)
# (10000, 16)
# (10000, 16, 1, 32, 32)
# (10000, 16)

# %%
# Solve the mixed Sudokus, where z is the number of common digits shared by 
# both puzzles, i.e. <z>=5-x.

#!python3 sep.py --ocase <z>

#You can change the value z in the following line. For reference,
#you can see the above line. I chose z = 3. You should choose according to your x value
# !python3 sep.py --ocase 3
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# use cuda
# ocase:  3
# use_cuda
# n_data:  10000
# base1:  1
# base2:  2
# Training Starts
# /kaggle/working/DRNets/Games/MNIST_Sudoku_4x4/sep.py:455: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   z = sep(torch.tensor(s_mix.reshape(-1, 1, 32, 32)).float()).cuda() #bs * 16, 2, 4, 100
# Iteration 0: total_loss: -1.367775, loss_recon: 0.000000, entropy_cell: 1.372175, entropy_alldiff: 1.381497
# epoch = 0, iter-0, label_acc = 0.046875, sudoku_acc= 0.000000
# 2,4,2,1, 2,3,2,3, 1,2,3,4, 2,4,5,3,
# 2,4,1,1, 2,2,2,5, 3,4,2,1, 3,5,4,2,
# 1,1,2,2, 2,3,5,5, 2,1,4,3, 5,3,2,4,
# ...

# %% [markdown]
# **I have manually interupted the further training to save time. But you can continue without interepting**
