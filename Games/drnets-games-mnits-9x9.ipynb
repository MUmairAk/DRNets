# %% [markdown]
# This Notebook runs the **[Deep Reasoning Networks (DRNets)](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence)** repository on Kaggle Notebook. The repository has two main parts:
#
# - [Crystal Structure Phase Mapping](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Crystal-Structure-Phase-Mapping)
# - [Games](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Games)
#
#
# This notebook runs the **Games** part which is further subdivided into:
#
# - [MNIST_Sudoku_4x4](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Games/MNIST_Sudoku_4x4)
# - [MNIST_Sudoku_9x9](https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence/tree/main/Games/MNIST_Sudoku_9x9)
#
# This Notebook runs **MNIST_Sudoku_9x9**

# %% [markdown]
# First, let's move to the desired directory.

# %%
#Clone the GitHub repo to a local directory named DRNets
# !git clone https://github.com/PiGrieco/DRNets-Nature-Machine-Intelligence.git DRNets
# Out:
# Cloning into 'DRNets'...
# remote: Enumerating objects: 269, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 269 (delta 0), reused 0 (delta 0), pack-reused 266
# Receiving objects: 100% (269/269), 148.32 MiB | 26.08 MiB/s, done.
# Resolving deltas: 100% (118/118), done.
# Updating files: 100% (224/224), done.

# %%
#Change to the MNIST_Sudoku_9x9 directory
# %cd /kaggle/working/DRNets/Games/MNIST_Sudoku_9x9
# Out:
# /kaggle/working/DRNets/Games/MNIST_Sudoku_9x9

# %% [markdown]
# Due to the large size of the original EMNIST dataset, we only used a subset of it to generate the Sudokus with letters. To better organize our data, we stored handwritten digits and handwritten letters in two zipped dictionaries:
#
# - **"selected_digits_offset2.npy.zip"**, and
# - **"selected_uppers_offset2.npy.zip"**.
#
# These two dictionary files should be unzipped into the current directory. Let's do that first!

# %%
#Unzip the data files
# !unzip -q /kaggle/working/DRNets/Games/MNIST_Sudoku_9x9/selected_digits_offset2.npy.zip
# !unzip -q /kaggle/working/DRNets/Games/MNIST_Sudoku_9x9/selected_uppers_offset2.npy.zip

# %% [markdown]
# The following line runs **gen_9by9_data.py** script to generate the data. But it is highly compyte-intensive. It requires more than 32GB of RAM. So, it is not possible to run on Kaggle or Google Colab. So, if you have more than 32 GB of RAM, then you can easily run this script.

# %%
#Generate Sudoku data where each digit is sampled from the MNIST/EMNIST dataset (takes about 10-20 mins)

# !python3 gen_9by9_data.py 10000 123

# %%
# Solve mixed Sudokus. On a machine with an NVIDIA Tesla V100 GPU, it takes 
# about 7 hours to converge. Manually terminate the training when it has 
# converged to the desired criteria (otherwise it will run the maximum number 
# of epochs).
# !python3 sep_9by9.py
